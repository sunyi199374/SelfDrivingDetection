# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin
from sklearn.datasets import load_sample_image
from sklearn.utils import shuffle
from time import time

def select_b_g_r(image):
    # blue color mask
    lower = np.uint8([  0, 0, 0])
    upper = np.uint8([255, 80, 80])
    blue_mask = cv2.inRange(image, lower, upper)
    
    # green color mask
    lower = np.uint8([  0, 0, 0])
    upper = np.uint8([100, 255, 100])
    green_mask = cv2.inRange(image, lower, upper)
    
    # red color mask
    lower = np.uint8([  0, 0, 0])
    upper = np.uint8([50, 50, 255])
    red_mask = cv2.inRange(image, lower, upper)
    
    hsv = convert_hsv(image)
    # yellow color mask HSV
    lower = np.uint8([ 80, 150, 20])
    upper = np.uint8([ 120, 255, 255])
    #lower = np.uint8([ 30, 20, 0])
    #upper = np.uint8([ 80, 100, 100])
    yellow_mask = cv2.inRange(hsv, lower, upper)
    
    # combine the mask
    mask_bg = cv2.bitwise_or(blue_mask, green_mask)
    #mask_ry = cv2.bitwise_or(red_mask, yellow_mask)
    mask_ry = cv2.bitwise_or(red_mask, yellow_mask)
    mask = cv2.bitwise_or(mask_bg,mask_ry)
    #mask = yellow_mask
    return cv2.bitwise_and(image, image, mask = mask)

def convert_hls(image):
    return cv2.cvtColor(image, cv2.COLOR_RGB2HLS)

def convert_hsv(image):
    return cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# %%
 
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
#vedioname = input("vedio name: ")
vedioname = 'r5.jpg'
frame = cv2.imread(vedioname)
    
frame = cv2.resize(frame, (640, 480))
#gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

r,c,n = frame.shape
midx = int(c/2)
midy = int(r/2)
offsetx = 80
offsety = 100
        #frame = frame[midx-offsetx:midx+offsetx, midy-offsety:midy+offsety]
        
    
        #equlizer in rgb
img_yuv = cv2.cvtColor(frame, cv2.COLOR_BGR2YUV)
        # equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
        # convert the YUV image back to RGB format
img = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
        
        #converting grayscale and resize
img = select_b_g_r(img)
#cv2.imshow('Frame',img)         
        #img = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
        

        #dilation process
kernel = np.ones((3,3),np.uint8)


gray = cv2.erode(img,kernel,iterations = 2)
gray = cv2.dilate(gray,kernel,iterations = 1)
gray = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)
gray = cv2.cvtColor(gray,cv2.COLOR_BGR2GRAY)
#cv2.imshow('Frame',img)  
#canny edge detection

 # Initiate STAR detector
#orb = cv2.ORB()

# find the keypoints with ORB
#kp = orb.detect(gray,None)

# compute the descriptors with ORB
#kp, gray = orb.compute(gray, kp)


#cv2.drawContours(gray, area, 3, (0,255,0), 3)
#gray_filtered = cv2.inRange(gray, 200,255)
# Threshold it so it becomes binary
ret, gray = cv2.threshold(gray,30,255,cv2.THRESH_BINARY)

gray = cv2.Canny(gray,80,150,apertureSize = 3)
#ret,thresh = cv2.threshold(gray, 127, 255, 0)
im2, contours, hierarchy = cv2.findContours(gray,1,2)


n = 0
la = 0
maxarea = 0
area = []
for cnt in contours:

    #if cv2.isContourConvex(contours[i]) == True:
        #if cv2.contourArea(contours[i])>80:
    [x,y,w,h] = cv2.boundingRect(cnt)  
    a = w*h
    if a > 100:
        cv2.drawContours(frame, cnt, -1, (0,0,0), 5)
        area.append(a)
    #cv2.rectangle(gray,(x,y),(x+w,y+h),(255,0,255),2)

        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)
        cv2.imshow('Frame',frame)  
cv2.waitKey(50000) & 0xFF == ord('q')
    

    #break

cv2.destroyAllWindows()

# %%
# Out:
# (159, 318, 3)
# (50562, 3)
# (50562, 1)
# (50562, 1)
# (50562, 5)
# Fitting model on a small sub-sample of the data
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 18.140270665038905
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 17.83165654821341
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 17.53251623901052
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 17.181815289099156
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 16.998901913247533
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 16.937906541390298
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 16.926151697304984
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 16.92189252236517
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 16.918544342418706
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 16.91579549592047
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 16.90868434324912
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 16.88727035965148
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 16.86322392264539
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 16.826812379380108
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 16.78835545985097
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 16.730135797452114
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 16.704442144807366
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 16.665405943608622
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 16.626039407230216
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 16.564295570791906
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 16.478276591335117
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 16.429677855837866
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 16.397963712699088
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 16.368614352924126
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 16.353731516229217
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 16.348134022994177
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 16.326627351054263
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 16.25334478876713
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 16.17413642817764
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 16.154693168338135
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 16.15295944619109
# center shift 2.260213e-03 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 17.609657221258594
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 16.06207199031996
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 15.972917102948546
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 15.955891727405334
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.95009442226794
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 15.94847170618242
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 15.948182470709343
# center shift 1.153348e-03 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 20.16536023195291
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 19.264126764478295
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 18.138868725369363
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 17.83990381195066
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 17.765004794359037
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 17.746019591519968
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 17.736745707644072
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 17.73572627760992
# center shift 2.257922e-03 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 15.616960194235062
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 15.29182173983141
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 15.193873382946077
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 15.172896593610282
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.172896593610282
# center shift 0.000000e+00 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 17.278534432929124
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 16.559521721587657
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 16.17127687311044
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 15.87367680298077
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.729632625377008
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 15.66452759513035
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 15.654440934196131
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 15.650606077516093
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 15.650606077516093
# center shift 0.000000e+00 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 16.248359734878385
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 15.392133650463446
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 15.221002720855482
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 15.168665938515622
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.168665938515622
# center shift 0.000000e+00 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 15.909547134220366
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 15.235289081797129
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 15.175822401044865
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 15.172896593610282
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.172896593610282
# center shift 0.000000e+00 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 18.90850052051509
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 18.37395104301611
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 18.269127407049687
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 18.204138663801416
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 18.144709623108877
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 18.109563034565234
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 18.098371210309626
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 18.087267304710338
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 18.080879126740292
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 18.075714798929006
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 18.07007683018022
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 18.06951127297562
# center shift 1.502654e-03 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 16.96683604808859
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 16.63017457296312
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 16.573006294751366
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 16.509616951866448
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 16.4305169609827
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 16.34211808221435
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 16.292497638304532
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 16.25167778562216
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 16.22155535978357
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 16.20867670334613
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 16.201592993350488
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 16.186759887436033
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 16.139394596797743
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 16.07178980913379
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 16.031582505129947
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 16.02858456108102
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 16.027879801672423
# center shift 1.169141e-03 within tolerance 8.403769e-06
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 18.848988020577217
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 17.607664688019405
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 16.731288181969404
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 16.173182486984402
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 15.977998680309511
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 15.947900433872132
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 15.947365084045632
# center shift 6.599368e-04 within tolerance 8.403769e-06
# done in 0.071s.
# Predicting color indices on the full image (k-means)
# done in 0.008s.
